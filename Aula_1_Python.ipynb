# %% [markdown]
# <a href="https://colab.research.google.com/github/mateus-bombassaro/python-ai-colab/blob/main/Aula_1_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Rodando IA no Google Colab

# %%
import os

from google.colab import userdata
userdata.get('GEMINI_API_KEY')

os.environ['GEMINI_API_KEY'] = userdata.get('GEMINI_API_KEY')

# %%
from google import genai

client = genai.Client()

# %%
resposta = client.models.generate_content(model="gemini-3.1-flash-lite", contents="O que é a Inteligência Artificial?")

# %%
print(resposta.text)
# Out:
# De forma simples, a **Inteligência Artificial (IA)** é um campo da ciência da computação que busca criar sistemas e máquinas capazes de realizar tarefas que, normalmente, exigiriam inteligência humana.
#
# Essas tarefas incluem coisas como aprender, raciocinar, tomar decisões, reconhecer padrões, entender idiomas e resolver problemas complexos.
#
# Para entender melhor, podemos dividir o conceito em três pilares principais:
#
# ### 1. Como a IA funciona?
# Ao contrário dos softwares tradicionais (onde o programador escreve regras fixas, como: *"se acontecer A, faça B"*), a IA moderna baseia-se no **Aprendizado de Máquina (Machine Learning)**.
# *   Em vez de receber ordens rígidas, o sistema é alimentado com uma quantidade gigantesca de dados.
# *   Ele analisa esses dados para identificar padrões e, a partir deles, começa a fazer previsões ou tomar decisões por conta própria.
#
# ### 2. Os principais tipos de IA
# *   **IA Estreita (ou Fraca):** É a IA que temos hoje. Ela é excelente em uma tarefa específica. Exemplo: o algoritmo que recomenda filmes na Netflix, o reconhecimento facial do seu celular ou o ChatGPT (que processa linguagem). Ela não tem consciência nem inteligência geral.
# *   **IA Geral (AGI):** É um conceito teórico de uma máquina que teria a capacidade intelectual humana completa, sendo capaz de aprender e executar *qualquer* tarefa que um ser humano faria. Isso ainda não existe.
#
# ### 3. Onde vemos a IA no dia a dia?
# Você provavelmente já usa IA várias vezes ao dia sem perceber:
# *   **Assistentes Virtuais:** Alexa, Siri e Google Assistente.
# *   **Sugestões de Conteúdo:** O que aparece no seu feed do Instagram, TikTok ou YouTube.
# *   **Tradução automática:** Como o Google Tradutor ou legendas automáticas.
# *   **Ferramentas de produtividade:** ChatGPT, Gemini ou Copilot, que escrevem textos, resumem reuniões e programam códigos.
# *   **Saúde:** Algoritmos que ajudam médicos a diagnosticar doenças através de exames de imagem com muito mais rapidez.
#
# ### O que a IA **NÃO** é?
# *   **Não é mágica:** É matemática, estatística e muita capacidade de processamento de dados.
# *   **Não tem consciência:** Mesmo que pareça que um chatbot está "pensando" ou "sentindo", ele apenas está prevendo qual a sequência de palavras mais provável com base em tudo o que ele já leu.
#
# **Em resumo:** A Inteligência Artificial é uma ferramenta poderosa que serve para **ampliar a capacidade humana**, automatizar tarefas repetitivas e analisar informações em uma escala que seria impossível para uma pessoa sozinha.
