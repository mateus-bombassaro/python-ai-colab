# %% [markdown]
# <a href="https://colab.research.google.com/github/mateus-bombassaro/python-ai-colab/blob/main/Aula_1_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Rodando IA no Google Colab

# %%
import os

from google.colab import userdata
userdata.get('GEMINI_API_KEY')

os.environ['GEMINI_API_KEY'] = userdata.get('GEMINI_API_KEY')

# %%
from google import genai

client = genai.Client()

# %%
resposta = client.models.generate_content(model="gemini-2.5-flash", contents="O que é a Inteligência Artificial?")

# %%
print(resposta.text)
# Out:
# De forma simples, a **Inteligência Artificial (IA)** é um campo da ciência da computação que busca criar sistemas e máquinas capazes de realizar tarefas que, normalmente, exigiriam inteligência humana.
#
# Essas tarefas incluem coisas como aprender, raciocinar, tomar decisões, reconhecer padrões, entender idiomas e resolver problemas complexos.
#
# Aqui estão os pontos principais para entender o que é e como funciona:
#
# ### 1. Como a IA funciona?
# Ao contrário de um software tradicional (onde um programador escreve regras fixas, como "se acontecer A, faça B"), a IA moderna é baseada principalmente em **Aprendizado de Máquina (Machine Learning)**.
# *   **Dados:** A máquina é alimentada com uma quantidade enorme de dados (textos, imagens, números).
# *   **Padrões:** Algoritmos analisam esses dados para encontrar padrões e correlações.
# *   **Previsão:** Com base no que aprendeu, a IA consegue fazer previsões ou gerar novos conteúdos sobre situações que nunca viu antes.
#
# ...

# %% [markdown]
# # Estruturas de Repetição, Loops, Laços

# %%
n = 1
texto = ""
while n <= 10:
  texto = texto + "*"
  n = n + 1
print(texto)
# Out:
# **********

# %% [markdown]
# # Dinâmica de chatbots e histórico de mensagens

# %%
chat = client.chats.create(model="gemini-2.5-flash")

# %%
resposta = chat.send_message("O que é inteligencia artificial")

# %%
print(resposta.text)
# Out:
# A **Inteligência Artificial (IA)** é um campo da ciência da computação focado em criar máquinas que podem simular ou replicar a inteligência humana. O objetivo principal é desenvolver sistemas capazes de realizar tarefas que, normalmente, exigiriam inteligência humana, como aprender, raciocinar, resolver problemas, perceber, compreender a linguagem e tomar decisões.
#
# Aqui estão os pontos chave para entender a IA:
#
# 1.  **Simulação da Inteligência Humana:** Não se trata de criar consciência, mas de imitar as capacidades cognitivas humanas. Uma IA não "sente" ou "compreende" da mesma forma que um ser humano, mas pode processar informações e produzir resultados que parecem inteligentes.
#
# ...

# %%
chat.send_message("Quando foi lançado o chat GPT?")
# Out:
# GenerateContentResponse(
#   automatic_function_calling_history=[],
#   candidates=[
#     Candidate(
#       content=Content(
#         parts=[
#           Part(
#             text='O ChatGPT foi lançado como uma **prévia de pesquisa (research preview)** pela OpenAI em **30 de novembro de 2022**.'
#           ),
#         ],
#         role='model'
#       ),
#       finish_reason=<FinishReason.STOP: 'STOP'>,
#       index=0
#     ),
#   ],
#   model_version='gemini-2.5-flash',
#   response_id='wmcpaq-_C-SEz7IP9c-QsQE',
#   sdk_http_response=HttpResponse(
#     headers=<dict len=11>
#   ),
#   usage_metadata=GenerateContentResponseUsageMetadata(
#     candidates_token_count=30,
#     prompt_token_count=911,
#     prompt_tokens_details=[
#       ModalityTokenCount(
#         modality=<MediaModality.TEXT: 'TEXT'>,
#         token_count=911
#       ),
#     ],
#     thoughts_token_count=358,
#     total_token_count=1299
#   )
# )

# %%
chat.get_history()
# Out:
# [UserContent(
#    parts=[
#      Part(
#        text='O que é inteligencia artificial'
#      ),
#    ],
#    role='user'
#  ),
#  Content(
#    parts=[
#      Part(
#        text="""A **Inteligência Artificial (IA)** é um campo da ciência da computação focado em criar máquinas que podem simular ou replicar a inteligência humana. O objetivo principal é desenvolver sistemas capazes de realizar tarefas que, normalmente, exigiriam inteligência humana, como aprender, raciocinar, resolver problemas, perceber, compreender a linguagem e tomar decisões.
#
#  Aqui estão os pontos chave para entender a IA:
#
#  1.  **Simulação da Inteligência Humana:** Não se trata de criar consciência, mas de imitar as capacidades cognitivas humanas. Uma IA não "sente" ou "compreende" da mesma forma que um ser humano, mas pode processar informações e produzir resultados que parecem inteligentes.
#
# ...

# %% [markdown]
# # Criando chatbot com Python e Gemini IA

# %%
prompt = input("Digite o seu prompt: ")

while prompt != "sair":
  resposta = chat.send_message(prompt)
  print(resposta.text)
  prompt = input("Digite o seu prompt: ")
# Out:
# Digite o seu prompt: O que é IA?
# A **Inteligência Artificial (IA)** é um campo da ciência da computação dedicado a criar sistemas e máquinas que podem simular ou replicar a inteligência humana. Em termos mais simples, é sobre fazer com que computadores e softwares consigam realizar tarefas que, se fossem feitas por um ser humano, exigiriam inteligência.
#
# O objetivo principal da IA é desenvolver máquinas capazes de:
#
# 1.  **Aprender:** Adquirir conhecimento e habilidades através de dados e experiência, sem serem explicitamente programadas para cada cenário (isso é a base do **Machine Learning**).
# 2.  **Raciocinar:** Aplicar lógica e regras para tirar conclusões e resolver problemas.
# 3.  **Perceber:** Interpretar informações do ambiente, seja através de imagens (Visão Computacional) ou sons (reconhecimento de fala).
# 4.  **Compreender a Linguagem:** Processar e gerar linguagem humana de forma significativa (Processamento de Linguagem Natural - PNL).
# ...

# %% [markdown]
# # Estrutura de Dados

# %% [markdown]
# Listas

# %%
lista_de_nome = ["Ana Silva", "Bruno Costa", "Carla Santos", "Daniel Oliveira",
    "Erica Souza", "Felipe Pereira"]

# %%
print(lista_de_nome[2])
# Out:
# Carla Santos

# %%
lista_de_medias = [8.9, 7.5, 4.2, 1.4, 9.5]

# %%
print(lista_de_medias[3])
# Out:
# 1.4

# %% [markdown]
# Desafio crie um código que percorra a lista e some 1 ponto, exceto quando o valor passar de 10, nota máxima

# %%
n = 0
while n < 5:
  if lista_de_medias[n] + 1 <= 10:
    lista_de_medias[n] = lista_de_medias[n] + 1
  else:
    lista_de_medias[n] = 10
  n = n + 1
print(lista_de_medias)
# Out:
# [9.9, 8.5, 5.2, 2.4, 10]

# %%
print(len(lista_de_medias))
# Out:
# 5

# %% [markdown]
# Usar dicionarios de forma que as chaves sejam nome e nota e valores sejam nomes e medias

# %%
dicio = {"Ana Silva": 8.9, "Bruno Costa": 7.5, "Carla Santos": 4.2, "Daniel Oliveira": 1.4, "Erica Souza": 9.5}

# %%
dicio_desafio = [
    {"nome": "Ana Silva", "media": 8.9},
    {"nome": "Bruno Costa", "media": 7.5},
    {"nome": "Carla Santos", "media": 4.2},
    {"nome": "Daniel Oliveira", "media": 1.4},
    {"nome": "Erica Souza", "media": 9.5}
]

# %%
dicio_desafio[0]["media"]
# Out:
# 8.9
